# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_excel('allDatesfinal.xlsx')
display(df)
df = df.iloc[1: , :]
df = df.tail(-1)
# Out:
#           date    World        EU    Europe   Austria   Denmark   Finland  \
# 0   2020-02-25    0.104     0.105     0.066     0.000     0.000     0.026
# 1   2020-02-26    0.118     0.156     0.097     0.000     0.000     0.051
# 2   2020-02-27    0.132     0.236     0.147     0.000     0.000     0.051
# 3   2020-02-28    0.135     0.321     0.201     0.000     0.000     0.077
# 4   2020-02-29    0.171     0.420     0.265     0.000     0.000     0.154
# ..         ...      ...       ...       ...       ...       ...       ...
# 722 2022-02-16  248.698  1680.691  1468.066  3365.465  7372.009  1183.953
# 723 2022-02-17  240.725  1538.762  1349.709  3296.967  7048.932  1059.026
# 724 2022-02-18  235.377  1468.612  1299.767  3272.545  6741.460   903.047
# 725 2022-02-19  230.778  1412.893  1255.000  2780.803  6470.014   850.000
# 726 2022-02-20  230.000  1386.077  1228.811  3134.760  6159.568   800.000
#
#        France   Germany    Greece  Hungary   Iceland  Ireland  Lithuania  \
# ...

# %%
print(df)
# Out:
#           date    World        EU    Europe   Austria   Denmark   Finland  \
# 2   2020-02-27    0.132     0.236     0.147     0.000     0.000     0.051
# 3   2020-02-28    0.135     0.321     0.201     0.000     0.000     0.077
# 4   2020-02-29    0.171     0.420     0.265     0.000     0.000     0.154
# 5   2020-03-01    0.196     0.615     0.390     0.221     0.000     0.154
# 6   2020-03-02    0.228     0.749     0.482     0.284     0.000     0.180
# ..         ...      ...       ...       ...       ...       ...       ...
# 722 2022-02-16  248.698  1680.691  1468.066  3365.465  7372.009  1183.953
# 723 2022-02-17  240.725  1538.762  1349.709  3296.967  7048.932  1059.026
# 724 2022-02-18  235.377  1468.612  1299.767  3272.545  6741.460   903.047
# 725 2022-02-19  230.778  1412.893  1255.000  2780.803  6470.014   850.000
# 726 2022-02-20  230.000  1386.077  1228.811  3134.760  6159.568   800.000
#
#        France   Germany    Greece  Hungary   Iceland  Ireland  Lithuania  \
# ...

# %%
wave1 = df.iloc[10:70]
for col in wave1.columns:
    wave1 = ((wave1 - wave1.min())/ (wave1.max() - wave1.min())*32).astype(int)
wave1 = wave1.iloc[: , 1:]
display(wave1)
# Out:
#     World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 12      0   0       0        0        0        0       0        0       0
# 13      0   0       0        0        0        0       0        0       0
# 14      0   0       0        0        3        0       0        0       0
# 15      0   1       1        0        5        2       0        0       0
# 16      1   1       1        1        8        4       0        0       3
# 17      1   3       2        2       10        5       0        1       4
# 18      1   3       3        2       10        6       0        2       7
# 19      2   4       4        3       11        7       0        3       7
# 20      3   5       5        4       11        8       1        4       9
# 21      3   6       6        6        9        9       1        5      10
# 22      4   8       7        7        8        9       2        7      10
# 23      5  10       9        9        7        9       2        9       9
# ...

# %%
wave2 = df.iloc[238:298]
for col in wave2.columns:
    wave2 = ((wave2 - wave2.min())/ (wave2.max() - wave2.min())*32).astype(int)
wave2 = wave2.iloc[: , 1:]
display(wave2)
# Out:
#      World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 240      0   0       0        0        0        0      10        0       0
# 241      1   2       2        1        0        0      11        1       1
# 242      2   4       5        2        1        0      13        3       1
# 243      4   5       5        3        1        0      11        4       2
# 244      5  10      10        4        2        0      16        5       3
# 245      7  12      12        5        3        0      17        6       5
# 246      8  14      14        6        3        1      18        7       6
# 247     10  17      17        8        3        2      19       11       8
# 248     10  19      19       10        4        2      19       12      10
# 249     11  20      20       12        4        3      18       13      12
# 250     13  23      22       13        4        3      22       14      13
# ...

# %%
wave3 = df.iloc[300:360]
for col in wave3.columns:
    wave3 = ((wave3 - wave3.min())/ (wave3.max() - wave3.min())*32).astype(int)
wave3 = wave3.iloc[: , 1:]
display(wave3)
# Out:
#      World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 302     23  21      23       26       32       10       6       32      14
# 303     20  21      23       28       30        9       7       31      13
# 304     19  17      21       27       27        5       9       23       9
# 305     17  12      18       22       25        1       3       21       7
# 306     17  10      17       21       24        1       1       23       7
# 307     17   9      17       21       23        0       0       21       8
# 308     17   8      17       21       23        1       0       17       8
# 309     19  10      18       24       22        1       5       17       9
# 310     20  11      19       24       22        0       4       16       8
# 311     21  13      21       25       21        2       3       19       8
# 312     22  14      21       25       20        2       4       18       9
# ...

# %%
wave4 = df.iloc[481:541]
for col in wave4.columns:
    wave4 = ((wave4 - wave4.min())/ (wave4.max() - wave4.min())*32).astype(int)
wave4 = wave4.iloc[: , 1:]
display(wave4)
# Out:
#      World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 483      0   0       0        1        1        0       0        1       0
# 484      0   0       0        1        1        0       0        1       0
# 485      0   0       0        1        0        0       0        1       0
# 486      0   0       1        1        0        1       0        1       0
# 487      0   0       1        1        0        1       0        0       0
# 488      1   0       2        1        0        2       0        0       0
# 489      0   0       3        0        0        2       0        0       0
# 490      0   0       3        0        0        3       0        0       0
# 491      1   0       4        0        1        4       0        0       1
# 492      1   1       5        0        2        4       0        0       2
# 493      1   2       6        0        3        5       0        0       3
# ...

# %%
wave5 = df.iloc[603:663]
for col in wave5.columns:
    wave5 = ((wave5 - wave5.min())/ (wave5.max() - wave5.min())*32).astype(int)
wave5 = wave5.iloc[: , 1:]
display(wave5)
# Out:
#      World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 605      0   0       0        0        0        0       0        0       0
# 606      0   0       0        0        0        0       0        0       0
# 607      0   0       1        1        0        0       0        0       1
# 608      0   1       1        1        1        0       0        0       1
# 609      1   2       2        2        1        0       0        1       2
# 610      0   2       3        2        1        1       0        2       1
# 611      1   3       3        2        2        1       0        1       1
# 612      1   4       4        3        2        1       0        3       3
# 613      2   4       5        4        2        1       0        5       4
# 614      2   4       5        5        2        1       0        4       6
# 615      1   4       5        5        2        1       0        4       9
# ...

# %%
wave6 = df.iloc[666:726]
for col in wave6.columns:
    wave6 = ((wave6 - wave6.min())/ (wave6.max() - wave6.min())*32).astype(int)
wave6 = wave6.iloc[: , 1:]
display(wave6)
# Out:
#      World  EU  Europe  Austria  Denmark  Finland  France  Germany  Greece  \
# 668      0   0       0        0        2        0       0        1       0
# 669      0   0       0        0        1        0       0        0       0
# 670      1   0       0        0        0        0       0        0       1
# 671      2   0       1        0        3        2       0        0       3
# 672      3   1       2        0        2        5       2        0       6
# 673      5   3       3        0        4        8       4        0      11
# 674      6   5       5        0        5       11       5        0      16
# 675      7   6       7        0        6       13       7        1      19
# 676      7   8       8        0        8       17       9        0      21
# 677      9   8       9        0        9       18      10        0      25
# 678     11   9      10        1        5       19      10        1      29
# ...

# %%
wave1.to_csv('wave1.csv', index=False)
wave2.to_csv('wave2.csv', index=False)
wave3.to_csv('wave3.csv', index=False)
wave4.to_csv('wave4.csv', index=False)
wave5.to_csv('wave5.csv', index=False)
wave6.to_csv('wave6.csv', index=False)
